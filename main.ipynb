# %%
import pandas as pd
from train import train_and_evaluate_model

# %%
df = pd.read_csv('data200k.csv', index_col=[0])

# %%
model, metrics, predictions, ground_truth = train_and_evaluate_model(df)

# %%
print("\nModel Performance Metrics:")
print(f"RMSE: {metrics['RMSE']:.2f} seconds")
print(f"R2 Score: {metrics['R2']:.3f}")
print(f"Test Set Size: {metrics['Test_Size']} incidents")
# Out:
# Model Performance Metrics:
# RMSE: 120.60 seconds
# R2 Score: 0.059
# Test Set Size: 19249 incidents

# %%
import matplotlib.pyplot as plt

# %%
import numpy
bins = numpy.linspace(0, 600, 50)
plt.hist(predictions, bins, label='x', alpha=0.5)
plt.hist(ground_truth, bins, label='y', alpha=0.5)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
ground_truth
# Out:
# 26944555    305.0
# 20625631    548.0
# 14073985    392.0
# 4545489     289.0
# 3964569     213.0
#             ...
# 24567347    356.0
# 25232601    311.0
# 68037       580.0
# 18752515    371.0
# 21003858    431.0
# Name: INCIDENT_RESPONSE_SECONDS_QY, Length: 19249, dtype: float64
